# %% [markdown]
# Definicion del path

# %%
import sys
import os
import importlib

sys.path.append(os.path.abspath("../src/consultas"))

# %% [markdown]
# 1. Se informa de cada ultimo trimestre registrado en cada año almacenado el porcentaje de personas mayores a 6 años capaces e incapaces de leer y
# escribir.

# %%
from consulta_leer_escribir import calcular_porcentajes_lectura
calcular_porcentajes_lectura()
# Out:
# Año: 2017, Trimestre: 1
# 📚 Mayores de 6 años, Capaces de leer: 98.4%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.59%
# ----------------------------------------
# Año: 2018, Trimestre: 2
# 📚 Mayores de 6 años, Capaces de leer: 98.31%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.68%
# ----------------------------------------
# Año: 2023, Trimestre: 1
# 📚 Mayores de 6 años, Capaces de leer: 98.53%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.47%
# ----------------------------------------
# Año: 2024, Trimestre: 1
# 📚 Mayores de 6 años, Capaces de leer: 98.55%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.42%
# ----------------------------------------

# %% [markdown]
# 2. El usuario ingresa un año y trimestre, y en base a eso se informa el porcentaje de personas no nacidas en Argentina que cursaron al menos un nivel universitario o superior.

# %%
from porcentaje_ext_uni import porcentaje_extranjeros_universitarios

porcentaje_extranjeros_universitarios()
# Out:
# El porcentaje de personas no nacidas en Argentina con nivel universitario o superior es: 0.77%

# %% [markdown]
# 3. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 4. Devuelve un Ranking de los 5 aglomerados con mayor porcentaje de hogares con dos o más ocupantes con estudios universitarios del ultimo par de archivos mas recientes

# %%
from ranking5 import ranking_englomerados_nivelSup as ren 

resultados = ren()


#Imprimo los resultados
print('')
print("Top 5 aglomerados por porcentaje de educación superior:\n")
print("{:<15} {:<10} {:<15} {:<10}".format('aglomerado', 'Total', 'Con Superior', 'Porcentaje'))
print("-"*50)

for aglomerado, data in resultados.items():
     print("{:<15} {:<10} {:<15} {:.2f}%".format(
          aglomerado,
          data['Total'],
          data['Tiene Superior'],
          data['Porcentaje']
     ))
# Out:
# El año seleccionado fue 2024 y el trimestre fue 1
#
# Top 5 aglomerados por porcentaje de educación superior:
#
# aglomerado      Total      Con Superior    Porcentaje
# --------------------------------------------------
# 19              461        138             29.93%
# 32              664        183             27.56%
# 23              595        157             26.39%
# 25              433        112             25.87%
# 22              428        107             25.00%

# %% [markdown]
# 5. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 6. Se informa el aglomerado con mayor cantidad de viviendas con más de dos ocupantes
# y sin baño

# %%
from aglomerados_sin_baños import filtrar_y_contar_viviendas_precarias
filtrar_y_contar_viviendas_precarias()
# Out:
# 📈 El aglomerado con mayor cantidad de viviendas con más de dos ocupantes y sin baño es Partidos del GBA con 34 viviendas.

# %% [markdown]
# 7. Informa por aglomerado el porcentaje de personas que cursaron al menos un nivel universitario o superior.

# %%
from calcular_porc_por_aglomerado import porcentaje_universitarios_por_aglomerado, obtener_individuos

individuos = obtener_individuos()

porcentaje_universitarios_por_aglomerado(individuos)
# Out:
# ------------------------------------------------------------------------------------------
# Porcentaje de personas, por aglomerado, que cursaron al menos un nivel universitario.
# ------------------------------------------------------------------------------------------
# Concordia : 17.59
# Gran Resistencia : 18.88
# Partidos del GBA : 19.07
# Rawson - Trelew : 19.83
# San Nicolás - Villa Constitución : 19.99
# Gran San Juan : 20.08
# Formosa : 20.24
# Santiago del Estero - La Banda : 20.79
# Santa Rosa - Toay : 20.87
# Neuquén - Plottier : 21.03
# Comodoro Rivadavia - Rada Tilly : 21.26
# Ushuaia - Río Grande : 21.57
# Río Gallegos : 21.67
# Gran San Luis : 21.88
# Gran Tucumán - Tafí Viejo : 22.75
# Viedma - Carmen de Patagones : 24.38
# Gran Rosario : 24.41
# Posadas : 24.79
# Mar del Plata : 25.42
# Río Cuarto : 25.55
# Gran Santa Fé : 25.8
# Gran Salta : 25.82
# Gran Catamarca : 26.0
# Gran Córdoba : 26.16
# Gran Mendoza : 26.26
# La Rioja : 26.62
# Bahía Blanca - Cerri : 27.21
# None : 27.85
# Jujuy - Palpalá : 28.01
# Corrientes : 28.89
# Gran La Plata : 31.34
# Ciudad Autonoma de Buenos Aires : 43.37

# %% [markdown]
# 8. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 9. Imprime una tabla que contiene la cantidad de personas mayores de edad según su nivel de estudios alcanzados, en base a un aglomerado seleccionado

# %%
import mayores_nivel_ed

mayores_nivel_ed.planilla_mas18_conAglomerado()
# Out:
# Aglomerados disponibles:
# 2 - Gran La Plata
# 3 - Bahía Blanca - Cerri
# 4 - Gran Rosario
# 5 - Gran Santa Fé
# 6 - Gran Paraná
# 7 - Posadas
# 8 - Gran Resistencia
# 9 - Comodoro Rivadavia - Rada Tilly
# 10 - Gran Mendoza
# 12 - Corrientes
# 13 - Gran Córdoba
# 14 - Concordia
# 15 - Formosa
# 17 - Neuquén - Plottier
# 18 - Santiago del Estero - La Banda
# 19 - Jujuy - Palpalá
# 20 - Río Gallegos
# 22 - Gran Catamarca
# 23 - Gran Salta
# 25 - La Rioja
# 26 - Gran San Luis
# 27 - Gran San Juan
# 29 - Gran Tucumán - Tafí Viejo
# 30 - Santa Rosa - Toay
# 31 - Ushuaia - Río Grande
# 32 - Ciudad Autonoma de Buenos Aires
# 33 - Partidos del GBA
# 34 - Mar del Plata
# 36 - Río Cuarto
# 38 - San Nicolás - Villa Constitución
# 91 - Rawson - Trelew
# 93 - Viedma - Carmen de Patagones
#
# Planilla de personas +18 según su nivel de estudios para el aglomerado de Viedma - Carmen de Patagones:
#
# Año-trimestre        Primario inc.        Primario comp.       Secundario inc.      Secundario comp.     Superior
# ------------------------------------------------------------------------------------------------------------------------
# 2017 - T 1           217                  137                  237                  199                  283
# 2018 - T 1           192                  170                  276                  228                  301
# 2018 - T 2           214                  181                  253                  238                  369
# 2023 - T 1           165                  165                  197                  230                  258
# 2024 - T 1           126                  159                  180                  238                  237

# %% [markdown]
# 10. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 11. Al usuario se le pide que ingrese un año. Se busqua en el último trimestre almacenado
# del mencionado año, el aglomerado con mayor porcentaje de viviendas de “Material
# precario” y el aglomerado con menor porcentaje de viviendas de “Material precario”.

# %%
from consulta_materialprecario import precarious_percentage

precarious_percentage()
# Out:
# 📈 El código de aglomerado con mayor porcentaje de viviendas con materiales precarios es Gran San Juan con un 21%
# 📉 El código de aglomerado con menor porcentaje de viviendas con materiales precarios es Santiago del Estero - La Banda con un 1%

# %% [markdown]
# 12. Informa el porcentaje por aglomerado de jubilados que vivien en una condicion de habitabilidad insuficiente, a partir de la informacion del ultimo trimestre que se almaceno.

# %%
from calcular_porc_por_aglomerado import porcentaje_jubilados_condicion_insuficiente


porcentaje_jubilados_condicion_insuficiente(individuos)
# Out:
# ------------------------------------------------------------------------------------------
# Porcentaje de jubilados en el ultimo trimestre, por aglomerado, que se encueuntran en condicion de habitabilidad insuficiente
# ------------------------------------------------------------------------------------------
# Santiago del Estero - La Banda : 4.94
# Gran Tucumán - Tafí Viejo : 6.69
# Gran Córdoba : 7.38
# Gran San Juan : 7.73
# Corrientes : 8.57
# Gran Resistencia : 8.74
# Posadas : 8.8
# Formosa : 8.98
# Partidos del GBA : 8.99
# Gran Catamarca : 9.4
# Ushuaia - Río Grande : 9.64
# Jujuy - Palpalá : 10.25
# Concordia : 10.27
# Gran La Plata : 10.48
# La Rioja : 10.54
# Gran Salta : 10.57
# Gran Mendoza : 10.65
# San Nicolás - Villa Constitución : 10.88
# Gran Rosario : 10.9
# Mar del Plata : 11.12
# Gran San Luis : 11.26
# Río Cuarto : 11.28
# Neuquén - Plottier : 11.47
# Comodoro Rivadavia - Rada Tilly : 11.71
# Bahía Blanca - Cerri : 13.0
# Gran Santa Fé : 13.14
# None : 13.28
# Rawson - Trelew : 13.35
# Santa Rosa - Toay : 14.17
# Ciudad Autonoma de Buenos Aires : 14.84
# Viedma - Carmen de Patagones : 15.13
# Río Gallegos : 16.38

# %% [markdown]
# 13. #EXPLICACION

# %%
#LLAMADO A LA FUNCION
