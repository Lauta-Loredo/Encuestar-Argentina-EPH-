# %% [markdown]
# Definicion del path

# %%
import sys
import os
import importlib

sys.path.append(os.path.abspath("../src/consultas"))
sys.path.append(os.path.abspath("../src/funciones"))

# %% [markdown]
# 1. Se informa de cada ultimo trimestre registrado en cada año almacenado el porcentaje de personas mayores a 6 años capaces e incapaces de leer y
# escribir.

# %%
from consulta_leer_escribir import calcular_porcentajes_lectura
calcular_porcentajes_lectura()
# Out:
# Año: 2019, Trimestre: 2
# 📚 Mayores de 6 años, Capaces de leer: 98.3%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.7%
# ----------------------------------------
# Año: 2020, Trimestre: 2
# 📚 Mayores de 6 años, Capaces de leer: 98.46%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.54%
# ----------------------------------------
# Año: 2021, Trimestre: 2
# 📚 Mayores de 6 años, Capaces de leer: 98.34%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.65%
# ----------------------------------------

# %% [markdown]
# 2. El usuario ingresa un año y trimestre, y en base a eso se informa el porcentaje de personas no nacidas en Argentina que cursaron al menos un nivel universitario o superior.

# %%
from porcentaje_ext_uni import porcentaje_extranjeros_universitarios

porcentaje_extranjeros_universitarios()
# Out:
# El porcentaje de personas no nacidas en Argentina con nivel universitario o superior es: N/A%

# %% [markdown]
# 3. Recorre todo el DataSet de Individuos y busca el año y trimestre con menor desocupación y retorna el porcentaje.

# %%
from menor_des import menor_des as ms

ms()
# Out:
# El año 2023 y trimestre 1 tienen el menor porcentaje de desocupación: 2%.

# %% [markdown]
# 4. Devuelve un Ranking de los 5 aglomerados con mayor porcentaje de hogares con dos o más ocupantes con estudios universitarios del ultimo par de archivos mas recientes

# %%
from ranking5 import ranking_englomerados_nivelSup as ren 

resultados = ren()


#Imprimo los resultados
print('')
print("Top 5 aglomerados por porcentaje de educación superior:\n")
print("{:<15} {:<10} {:<15} {:<10}".format('aglomerado', 'Total', 'Con Superior', 'Porcentaje'))
print("-"*50)

for aglomerado, data in resultados.items():
     print("{:<15} {:<10} {:<15} {:.2f}%".format(
          aglomerado,
          data['Total'],
          data['Tiene Superior'],
          data['Porcentaje']
     ))
# Out:
# El año seleccionado fue 2021 y el trimestre fue 2
#
# Top 5 aglomerados por porcentaje de educación superior:
#
# aglomerado      Total      Con Superior    Porcentaje
# --------------------------------------------------
# 32              386        135             34.97%
# 2               432        133             30.79%
# 23              713        207             29.03%
# 19              545        141             25.87%
# 12              406        103             25.37%

# %% [markdown]
# 5. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 6. Se informa el aglomerado con mayor cantidad de viviendas con más de dos ocupantes
# y sin baño

# %%
from aglomerados_sin_baños import filtrar_y_contar_viviendas_precarias
filtrar_y_contar_viviendas_precarias()
# Out:
# 📈 El aglomerado con mayor cantidad de viviendas con más de dos ocupantes y sin baño es Partidos del GBA con 21 viviendas.

# %% [markdown]
# 7. Informa por aglomerado el porcentaje de personas que cursaron al menos un nivel universitario o superior.

# %%
from calcular_porc_por_aglomerado import porcentaje_universitarios_por_aglomerado, obtener_individuos

individuos = obtener_individuos()

porcentaje_universitarios_por_aglomerado(individuos)
# Out:
# ------------------------------------------------------------------------------------------
# Porcentaje de personas, por aglomerado, que cursaron al menos un nivel universitario.
# ------------------------------------------------------------------------------------------
# Concordia : 16.86
# Gran Resistencia : 18.63
# Gran San Juan : 19.52
# San Nicolás - Villa Constitución : 19.94
# Santiago del Estero - La Banda : 20.19
# Formosa : 20.32
# Comodoro Rivadavia - Rada Tilly : 20.5
# Santa Rosa - Toay : 20.82
# Ushuaia - Río Grande : 21.43
# Partidos del GBA : 21.79
# Rawson - Trelew : 21.8
# Río Gallegos : 21.85
# Neuquén - Plottier : 22.14
# Gran Tucumán - Tafí Viejo : 23.1
# Gran San Luis : 23.4
# Gran Rosario : 23.7
# Posadas : 25.35
# Viedma - Carmen de Patagones : 25.67
# La Rioja : 25.91
# Gran Córdoba : 26.15
# Gran Catamarca : 26.61
# Gran Salta : 26.85
# Gran Santa Fé : 26.96
# Río Cuarto : 27.01
# Gran Mendoza : 27.25
# Corrientes : 27.37
# Bahía Blanca - Cerri : 28.07
# Mar del Plata : 28.09
# Jujuy - Palpalá : 28.92
# None : 29.13
# Gran La Plata : 32.08
# Ciudad Autonoma de Buenos Aires : 46.4

# %% [markdown]
# 8. Recorre el DataSet de Hogares y ordena en una lista de forma descendente las regiones por medio del porcentaje de inquilinos en cada una.

# %%
from porcentaje_inqui import porcentaje_inqui as pi

pi()
# Out:
# [{'region': '44', 'porcentaje_inquilinos': 24.08630559225011}, {'region': '43', 'porcentaje_inquilinos': 20.628850647971106}, {'region': '42', 'porcentaje_inquilinos': 19.015280135823428}, {'region': '1', 'porcentaje_inquilinos': 18.543720190779016}, {'region': '41', 'porcentaje_inquilinos': 14.327315084449621}, {'region': '40', 'porcentaje_inquilinos': 13.717863003707532}]

# %% [markdown]
# 9. Imprime una tabla que contiene la cantidad de personas mayores de edad según su nivel de estudios alcanzados, en base a un aglomerado seleccionado

# %%
import mayores_nivel_ed

mayores_nivel_ed.planilla_mas18_conAglomerado()
# Out:
# Aglomerados disponibles:
# 2 - Gran La Plata
# 3 - Bahía Blanca - Cerri
# 4 - Gran Rosario
# 5 - Gran Santa Fé
# 6 - Gran Paraná
# 7 - Posadas
# 8 - Gran Resistencia
# 9 - Comodoro Rivadavia - Rada Tilly
# 10 - Gran Mendoza
# 12 - Corrientes
# 13 - Gran Córdoba
# 14 - Concordia
# 15 - Formosa
# 17 - Neuquén - Plottier
# 18 - Santiago del Estero - La Banda
# 19 - Jujuy - Palpalá
# 20 - Río Gallegos
# 22 - Gran Catamarca
# 23 - Gran Salta
# 25 - La Rioja
# 26 - Gran San Luis
# 27 - Gran San Juan
# 29 - Gran Tucumán - Tafí Viejo
# 30 - Santa Rosa - Toay
# 31 - Ushuaia - Río Grande
# 32 - Ciudad Autonoma de Buenos Aires
# 33 - Partidos del GBA
# 34 - Mar del Plata
# 36 - Río Cuarto
# 38 - San Nicolás - Villa Constitución
# 91 - Rawson - Trelew
# 93 - Viedma - Carmen de Patagones
#
# Planilla de personas +18 según su nivel de estudios para el aglomerado de Gran La Plata:
#
# Año-trimestre        Primario inc.        Primario comp.       Secundario inc.      Secundario comp.     Superior
# ------------------------------------------------------------------------------------------------------------------------
# 2019 - T 2           204                  166                  286                  267                  445
# 2020 - T 2           113                  91                   157                  150                  263
# 2021 - T 2           143                  124                  252                  191                  440

# %% [markdown]
# 10. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 11. Al usuario se le pide que ingrese un año. Se busqua en el último trimestre almacenado
# del mencionado año, el aglomerado con mayor porcentaje de viviendas de “Material
# precario” y el aglomerado con menor porcentaje de viviendas de “Material precario”.

# %%
from consulta_materialprecario import precarious_percentage

precarious_percentage()
# Out:
# ⚠️ El año 2024 no se encuentra en los datos.

# %% [markdown]
# 12. Informa el porcentaje por aglomerado de jubilados que vivien en una condicion de habitabilidad insuficiente, a partir de la informacion del ultimo trimestre que se almaceno.

# %%
from calcular_porc_por_aglomerado import porcentaje_jubilados_condicion_insuficiente


porcentaje_jubilados_condicion_insuficiente(individuos)
# Out:
# ------------------------------------------------------------------------------------------
# Porcentaje de jubilados en el ultimo trimestre, por aglomerado, que se encueuntran en condicion de habitabilidad insuficiente
# ------------------------------------------------------------------------------------------
# Ushuaia - Río Grande : 10.73
# Jujuy - Palpalá : 11.33
# Gran Salta : 11.53
# Santiago del Estero - La Banda : 11.98
# Río Gallegos : 12.42
# La Rioja : 13.02
# Gran Tucumán - Tafí Viejo : 13.27
# Gran Córdoba : 13.4
# Gran La Plata : 13.48
# Corrientes : 13.73
# Posadas : 14.14
# Neuquén - Plottier : 14.25
# Comodoro Rivadavia - Rada Tilly : 14.59
# Gran Santa Fé : 15.06
# Gran Mendoza : 15.99
# Partidos del GBA : 16.07
# Gran Catamarca : 16.15
# Gran Rosario : 16.43
# Rawson - Trelew : 16.57
# Concordia : 16.59
# Gran Resistencia : 16.79
# Santa Rosa - Toay : 17.28
# Gran San Juan : 17.44
# Río Cuarto : 17.82
# Bahía Blanca - Cerri : 17.9
# Formosa : 18.11
# San Nicolás - Villa Constitución : 18.97
# Viedma - Carmen de Patagones : 19.15
# Mar del Plata : 19.17
# Gran San Luis : 19.22
# Ciudad Autonoma de Buenos Aires : 21.18
# None : 23.37

# %% [markdown]
# 13. A partir del año ingresado por teclado y el ultimo trimestre del mismo informa cuantas personas cursaron el nivel universitario o superior y que vivan en una vivienda con condicion de habitalida insuficiente.

# %%
import hog_insu as hi

importlib.reload(hi)

hi.hog_insu()
# Out:
# Cantidad de personas en viviendas con condición insuficiente y nivel universitario o superior: 8332
