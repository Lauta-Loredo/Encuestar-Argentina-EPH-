# %% [markdown]
# Definicion del path

# %%
import sys
import os
import importlib

sys.path.append(os.path.abspath("../src/consultas"))

# %% [markdown]
# 1. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 2. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 3. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 4. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 5. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 6. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 7. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 8. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 9. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 10. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 11. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 12. #EXPLICACION

# %%
#LLAMADO A LA FUNCION

# %% [markdown]
# 13. #EXPLICACION

# %%
#LLAMADO A LA FUNCION
