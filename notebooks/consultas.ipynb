# %% [markdown]
# Definicion del path

# %%
import sys
import os
import importlib

sys.path.append(os.path.abspath("../src/consultas"))
sys.path.append(os.path.abspath("../src/funciones"))

# %% [markdown]
# 1. Se informa de cada ultimo trimestre registrado en cada año almacenado el porcentaje de personas mayores a 6 años capaces e incapaces de leer y
# escribir.

# %%
from consulta_leer_escribir import calcular_porcentajes_lectura
calcular_porcentajes_lectura()
# Out:
# Año: 2024, Trimestre: 3
# 📚 Mayores de 6 años, Capaces de leer: 98.56%
# 🚫📖 Mayores de 6 años, Incapaces de leer: 1.44%
# ----------------------------------------

# %% [markdown]
# 2. El usuario ingresa un año y trimestre, y en base a eso se informa el porcentaje de personas no nacidas en Argentina que cursaron al menos un nivel universitario o superior.

# %%
from porcentaje_ext_uni import porcentaje_extranjeros_universitarios

porcentaje_extranjeros_universitarios()
# Out:
# El porcentaje de personas no nacidas en Argentina con nivel universitario o superior es: 0.81%

# %% [markdown]
# 3. Recorre todo el DataSet de Individuos y busca el año y trimestre con menor desocupación y retorna el porcentaje.

# %%
from menor_des import menor_des as ms

ms()
# Out:
# El año 2024 y trimestre 3 tienen el menor porcentaje de desocupación: 2%.

# %% [markdown]
# 4. Devuelve un Ranking de los 5 aglomerados con mayor porcentaje de hogares con dos o más ocupantes con estudios universitarios del ultimo par de archivos mas recientes

# %%
from ranking5 import ranking_englomerados_nivelSup as ren 

resultados = ren()


#Imprimo los resultados
print('')
print("Top 5 aglomerados por porcentaje de educación superior:\n")
print("{:<15} {:<10} {:<15} {:<10}".format('aglomerado', 'Total', 'Con Superior', 'Porcentaje'))
print("-"*50)

for aglomerado, data in resultados.items():
     print("{:<15} {:<10} {:<15} {:.2f}%".format(
          aglomerado,
          data['Total'],
          data['Tiene Superior'],
          data['Porcentaje']
     ))
# Out:
# El año seleccionado fue 2024 y el trimestre fue 3
#
# Top 5 aglomerados por porcentaje de educación superior:
#
# aglomerado      Total      Con Superior    Porcentaje
# --------------------------------------------------
# 32              678        229             33.78%
# 23              580        159             27.41%
# 12              353        94              26.63%
# 29              677        172             25.41%
# 19              488        122             25.00%

# %% [markdown]
# 5. Informa por cada aglomerado el porcentaje de ocupación por propietarios.

# %%
#LLAMADO A LA FUNCION
from calcular_porc_viviendas_prop import imprimir_viviendas_propias_por_aglomerado
imprimir_viviendas_propias_por_aglomerado()
# Out:
# ------------------------------------------------------------------------------------------
# Porcentaje de viviendas propias, por aglomerado
# ------------------------------------------------------------------------------------------
# Gran Córdoba : 50.86
# Ushuaia - Río Grande : 54.63
# Río Gallegos : 56.32
# Ciudad Autonoma de Buenos Aires : 56.93
# Gran Mendoza : 58.25
# Río Cuarto : 58.86
# Comodoro Rivadavia - Rada Tilly : 61.89
# Santa Rosa - Toay : 62.63
# Bahía Blanca - Cerri : 63.33
# Gran San Juan : 65.04
# Viedma - Carmen de Patagones : 65.7
# Gran La Plata : 67.01
# Rawson - Trelew : 67.3
# Gran San Luis : 67.62
# Neuquén - Plottier : 67.74
# Gran Tucumán - Tafí Viejo : 68.54
# Posadas : 70.16
# Gran Salta : 70.17
# San Nicolás - Villa Constitución : 70.38
# Gran Rosario : 70.48
# None : 70.95
# La Rioja : 71.83
# Corrientes : 72.24
# Partidos del GBA : 72.42
# Mar del Plata : 72.98
# Gran Santa Fé : 76.26
# Concordia : 76.57
# Jujuy - Palpalá : 77.05
# Formosa : 78.65
# Gran Catamarca : 81.95
# Gran Resistencia : 83.65
# Santiago del Estero - La Banda : 85.82

# %% [markdown]
# 6. Se informa el aglomerado con mayor cantidad de viviendas con más de dos ocupantes
# y sin baño

# %%
from aglomerados_sin_baños import filtrar_y_contar_viviendas_precarias
filtrar_y_contar_viviendas_precarias()
# Out:
# 📈 El aglomerado con mayor cantidad de viviendas con más de dos ocupantes y sin baño es Partidos del GBA con 5 viviendas.

# %% [markdown]
# 7. Informa por aglomerado el porcentaje de personas que cursaron al menos un nivel universitario o superior.

# %%
from calcular_porc_por_aglomerado import porcentaje_universitarios_por_aglomerado, obtener_individuos

individuos = obtener_individuos()

porcentaje_universitarios_por_aglomerado(individuos)
# Out:
# ------------------------------------------------------------------------------------------
# Porcentaje de personas, por aglomerado, que cursaron al menos un nivel universitario.
# ------------------------------------------------------------------------------------------
# Concordia : 17.01
# Rawson - Trelew : 17.8
# Gran San Juan : 20.18
# San Nicolás - Villa Constitución : 21.17
# Santiago del Estero - La Banda : 21.6
# Formosa : 21.71
# Ushuaia - Río Grande : 22.07
# Gran Resistencia : 22.73
# Comodoro Rivadavia - Rada Tilly : 22.74
# Partidos del GBA : 22.9
# Gran Catamarca : 23.26
# Río Gallegos : 23.32
# Gran Santa Fé : 24.52
# Viedma - Carmen de Patagones : 25.08
# Gran San Luis : 25.13
# Santa Rosa - Toay : 25.22
# La Rioja : 26.01
# Neuquén - Plottier : 26.2
# Mar del Plata : 26.92
# Posadas : 28.38
# Gran Salta : 28.79
# Gran Tucumán - Tafí Viejo : 28.85
# Gran Mendoza : 29.36
# Gran Rosario : 29.39
# Jujuy - Palpalá : 29.42
# Corrientes : 29.53
# Gran Córdoba : 29.84
# Río Cuarto : 30.21
# None : 30.65
# Gran La Plata : 31.64
# Bahía Blanca - Cerri : 33.0
# Ciudad Autonoma de Buenos Aires : 53.74

# %% [markdown]
# 8. Recorre el DataSet de Hogares y ordena en una lista de forma descendente las regiones por medio del porcentaje de inquilinos en cada una.

# %%
from porcentaje_inqui import porcentaje_inqui as pi

pi()
# Out:
# [{'region': '44', 'porcentaje_inquilinos': 26.423902894491132}, {'region': '43', 'porcentaje_inquilinos': 22.828096118299445}, {'region': '42', 'porcentaje_inquilinos': 22.013758599124454}, {'region': '1', 'porcentaje_inquilinos': 19.345559151384396}, {'region': '41', 'porcentaje_inquilinos': 14.579552329098608}, {'region': '40', 'porcentaje_inquilinos': 14.257748776508972}]

# %% [markdown]
# 9. Imprime una tabla que contiene la cantidad de personas mayores de edad según su nivel de estudios alcanzados, en base a un aglomerado seleccionado

# %%
import mayores_nivel_ed

mayores_nivel_ed.planilla_mas18_conAglomerado()
# Out:
# Aglomerados disponibles:
# 2 - Gran La Plata
# 3 - Bahía Blanca - Cerri
# 4 - Gran Rosario
# 5 - Gran Santa Fé
# 6 - Gran Paraná
# 7 - Posadas
# 8 - Gran Resistencia
# 9 - Comodoro Rivadavia - Rada Tilly
# 10 - Gran Mendoza
# 12 - Corrientes
# 13 - Gran Córdoba
# 14 - Concordia
# 15 - Formosa
# 17 - Neuquén - Plottier
# 18 - Santiago del Estero - La Banda
# 19 - Jujuy - Palpalá
# 20 - Río Gallegos
# 22 - Gran Catamarca
# 23 - Gran Salta
# 25 - La Rioja
# 26 - Gran San Luis
# 27 - Gran San Juan
# 29 - Gran Tucumán - Tafí Viejo
# 30 - Santa Rosa - Toay
# 31 - Ushuaia - Río Grande
# 32 - Ciudad Autonoma de Buenos Aires
# 33 - Partidos del GBA
# 34 - Mar del Plata
# 36 - Río Cuarto
# 38 - San Nicolás - Villa Constitución
# 91 - Rawson - Trelew
# 93 - Viedma - Carmen de Patagones
#
# Planilla de personas +18 según su nivel de estudios para el aglomerado de Posadas:
#
# Año-trimestre        Primario inc.        Primario comp.       Secundario inc.      Secundario comp.     Superior
# ------------------------------------------------------------------------------------------------------------------------
# 2024 - T 3           220                  114                  206                  231                  344

# %% [markdown]
# 10. Calculo para cada trimestre el porcentaje de personas mayores con secundario incompleto en los aglomerados que seleccionen.
# Se filtran los registros por edad y aglomerado y luego se agrupan por año y trimestre.

# %%
import mayores_sec_inc

mayores_sec_inc.calc_sec_inc_trim()
# Out:
# Aglomerados disponibles:
# 2 - Gran La Plata
# 3 - Bahía Blanca - Cerri
# 4 - Gran Rosario
# 5 - Gran Santa Fé
# 6 - Gran Paraná
# 7 - Posadas
# 8 - Gran Resistencia
# 9 - Comodoro Rivadavia - Rada Tilly
# 10 - Gran Mendoza
# 12 - Corrientes
# 13 - Gran Córdoba
# 14 - Concordia
# 15 - Formosa
# 17 - Neuquén - Plottier
# 18 - Santiago del Estero - La Banda
# 19 - Jujuy - Palpalá
# 20 - Río Gallegos
# 22 - Gran Catamarca
# 23 - Gran Salta
# 25 - La Rioja
# 26 - Gran San Luis
# 27 - Gran San Juan
# 29 - Gran Tucumán - Tafí Viejo
# 30 - Santa Rosa - Toay
# 31 - Ushuaia - Río Grande
# 32 - Ciudad Autonoma de Buenos Aires
# 33 - Partidos del GBA
# 34 - Mar del Plata
# 36 - Río Cuarto
# 38 - San Nicolás - Villa Constitución
# 91 - Rawson - Trelew
# 93 - Viedma - Carmen de Patagones
#
# Planilla de personas +18 con secundario incompleto:
# Año-Trimestre   Gran La Plata                  Bahía Blanca - Cerri
# --------------------------------------------------------------------------------
# 2024-T3         12.03%                         13.99%

# %% [markdown]
# 11. Al usuario se le pide que ingrese un año. Se busqua en el último trimestre almacenado
# del mencionado año, el aglomerado con mayor porcentaje de viviendas de “Material
# precario” y el aglomerado con menor porcentaje de viviendas de “Material precario”.

# %%
from consulta_materialprecario import precarious_percentage

precarious_percentage()
# Out:
# 📈 El aglomerado con mayor porcentaje de viviendas con materiales precarios es Gran San Juan con un 15%
# 📉 El aglomerado con menor porcentaje de viviendas con materiales precarios es Partidos del GBA con un 1%

# %% [markdown]
# 12. Informa el porcentaje por aglomerado de jubilados que vivien en una condicion de habitabilidad insuficiente, a partir de la informacion del ultimo trimestre que se almaceno.

# %%
from calcular_porc_por_aglomerado import porcentaje_jubilados_condicion_insuficiente


porcentaje_jubilados_condicion_insuficiente(individuos)
# Out:
# ------------------------------------------------------------------------------------------
# Porcentaje de jubilados en el ultimo trimestre, por aglomerado, que se encueuntran en condicion de habitabilidad insuficiente
# ------------------------------------------------------------------------------------------
# Gran Tucumán - Tafí Viejo : 7.0
# Gran San Juan : 7.42
# Gran Córdoba : 7.79
# Gran Resistencia : 8.32
# Santiago del Estero - La Banda : 8.6
# Gran San Luis : 8.62
# Ushuaia - Río Grande : 8.66
# Formosa : 8.84
# Partidos del GBA : 8.88
# Gran La Plata : 8.96
# Posadas : 9.16
# La Rioja : 9.22
# Gran Salta : 9.46
# Gran Mendoza : 10.08
# Jujuy - Palpalá : 10.11
# Concordia : 10.13
# Corrientes : 10.47
# Comodoro Rivadavia - Rada Tilly : 10.48
# Gran Catamarca : 10.57
# Santa Rosa - Toay : 11.41
# Río Cuarto : 11.49
# Neuquén - Plottier : 11.92
# Gran Rosario : 12.08
# Ciudad Autonoma de Buenos Aires : 12.32
# None : 12.52
# Gran Santa Fé : 12.7
# San Nicolás - Villa Constitución : 12.83
# Rawson - Trelew : 12.92
# Bahía Blanca - Cerri : 13.14
# Mar del Plata : 13.3
# Río Gallegos : 13.97
# Viedma - Carmen de Patagones : 16.37

# %% [markdown]
# 13. A partir del año ingresado por teclado y el ultimo trimestre del mismo informa cuantas personas cursaron el nivel universitario o superior y que vivan en una vivienda con condicion de habitalida insuficiente.

# %%
import hog_insu as hi

importlib.reload(hi)

hi.hog_insu()
# Out:
# Cantidad de personas en viviendas con condición insuficiente y nivel universitario o superior: 7907
