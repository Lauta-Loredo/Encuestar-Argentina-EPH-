# %% [markdown]
# Definicion del path

# %%
import sys
import os
import importlib

sys.path.append(os.path.abspath("../src"))

# %% [markdown]
# Juntamos los DataSets

# %%
from pathlib import Path
import DataSet as ds


folder = Path('../utils/data')

hogares = ds.dataset_hogares(folder)
for d in hogares:
    if '' in d:
        del d['']
    for clave, valor in d.items():
        # si es string y está vacío o sólo espacios…
        if isinstance(valor, str) and valor.strip() == '':
            d[clave] = 'sin información'

sys.path.append(os.path.abspath("../src/funciones"))
# Out:
# ✅ Se cargaron 16650 registros de hogares.

# %% [markdown]
# 7. La funcion key_tipo_hogar del modulo tipo_hogar agrega una nueva columna (key) a la variable hogares (pasada como parametro) y agrega valores en base a la cantidad de ocupantes del hogar

# %%
from tipo_hogar import key_tipo_hogar
key_tipo_hogar(hogares)
# Out:
# [{'CODUSU': 'TQRMNOQVSHMMLOCDEFJAH00808791',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '3',
#   'PONDERA': '228',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '5',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '5',
#   'II2': '4',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '975000',
#   'DECIFR': '6',
#   'IDECIFR': '6',
#   'RDECIFR': '6',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '6',
#   'ADECIFR': '5',
#   'IPCF': '975000',
#   'DECCFR': '9',
#   'IDECCFR': '10',
#   'RDECCFR': '9',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '10',
#   'ADECCFR': '9',
#   'PONDIH': '366',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOPTQHKLLSCDEFJAH00866946',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '3',
#   'PONDERA': '414',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '3',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '4',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': '12',
#   'RDECIFR': '12',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '12',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': '12',
#   'RDECCFR': '12',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '12',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORVTHMOLSCDEFJAH00808761',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '3',
#   'PONDERA': '586',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '6',
#   'IX_MEN10': '2',
#   'IX_MAYEQ10': '4',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': '12',
#   'RDECIFR': '12',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '12',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': '12',
#   'RDECCFR': '12',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '12',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Extendido'},
#  {'CODUSU': 'TQRMNORVVHMOLSCDEFJAH00866947',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '3',
#   'PONDERA': '536',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '3',
#   'IX_MEN10': '1',
#   'IX_MAYEQ10': '2',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': '12',
#   'RDECIFR': '12',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '12',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': '12',
#   'RDECCFR': '12',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '12',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOTPTHLNLRCDEFJAH00803474',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '3',
#   'PONDERA': '251',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '2',
#   'IX_MAYEQ10': '2',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': '12',
#   'RDECIFR': '12',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '12',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': '12',
#   'RDECCFR': '12',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '12',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '2',
#   'VII1_2': '0',
#   'VII2_1': '96',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORXRHKLKTCDEGIBJ00866948',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '12',
#   'PONDERA': '823',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '3',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '2',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '1',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '160000',
#   'DECIFR': '1',
#   'IDECIFR': '1',
#   'RDECIFR': '1',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '1',
#   'ADECIFR': '1',
#   'IPCF': '160000',
#   'DECCFR': '2',
#   'IDECCFR': '2',
#   'RDECCFR': '3',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '2',
#   'ADECCFR': '2',
#   'PONDIH': '837',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOSRPHJMKUCDEGIBJ00862108',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '12',
#   'PONDERA': '438',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '9',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '2',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '1',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '389000',
#   'DECIFR': '2',
#   'IDECIFR': '2',
#   'RDECIFR': '3',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '2',
#   'ADECIFR': '2',
#   'IPCF': '389000',
#   'DECCFR': '6',
#   'IDECCFR': '6',
#   'RDECCFR': '8',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '7',
#   'ADECCFR': '8',
#   'PONDIH': '444',
#   'VII1_1': '96',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOSTYHLOLMCDEGIBJ00804702',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '12',
#   'PONDERA': '274',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '8',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '8',
#   'II2': '6',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '9',
#   'IX_MEN10': '5',
#   'IX_MAYEQ10': '4',
#   'ITF': '1084000',
#   'DECIFR': '6',
#   'IDECIFR': '7',
#   'RDECIFR': '8',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '7',
#   'ADECIFR': '8',
#   'IPCF': '120444,44',
#   'DECCFR': '1',
#   'IDECCFR': '1',
#   'RDECCFR': '2',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '2',
#   'ADECCFR': '1',
#   'PONDIH': '275',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '5',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Extendido'},
#  {'CODUSU': 'TQRMNOSQTHMKKSCDEGIBJ00809872',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '12',
#   'PONDERA': '411',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '5',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '1',
#   'IV12_2': '1',
#   'IV12_3': '2',
#   'II1': '5',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '3',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '3',
#   'ITF': '1350000',
#   'DECIFR': '7',
#   'IDECIFR': '8',
#   'RDECIFR': '9',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '8',
#   'ADECIFR': '9',
#   'IPCF': '450000',
#   'DECCFR': '7',
#   'IDECCFR': '7',
#   'RDECCFR': '9',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '7',
#   'ADECCFR': '9',
#   'PONDIH': '442',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '2',
#   'VII2_2': '3',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOPSWHLOKTCDEFOCD00866949',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '8',
#   'PONDERA': '328',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '2',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': '12',
#   'RDECIFR': '12',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '12',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': '12',
#   'RDECCFR': '12',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '12',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '96',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQSMNORTQHMOLLCDEFOCD00852367',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '8',
#   'PONDERA': '464',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '1',
#   'IV3': '2',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '2',
#   'IV6': '2',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '2',
#   'IV10': '2',
#   'IV11': '2',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '1',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '6',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '2',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '2',
#   'IX_MAYEQ10': '2',
#   'ITF': '298000',
#   'DECIFR': '1',
#   'IDECIFR': '1',
#   'RDECIFR': '2',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '2',
#   'ADECIFR': '3',
#   'IPCF': '74500',
#   'DECCFR': '1',
#   'IDECCFR': '1',
#   'RDECCFR': '1',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '1',
#   'ADECCFR': '2',
#   'PONDIH': '547',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORQSHLNLLCDEFOCD00804266',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '8',
#   'PONDERA': '150',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '1',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '347800',
#   'DECIFR': '2',
#   'IDECIFR': '2',
#   'RDECIFR': '3',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '2',
#   'ADECIFR': '4',
#   'IPCF': '173900',
#   'DECCFR': '2',
#   'IDECCFR': '2',
#   'RDECCFR': '4',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '3',
#   'ADECCFR': '5',
#   'PONDIH': '210',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOQVXHJLLNCDEFOCD00862122',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '8',
#   'PONDERA': '414',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '4',
#   'ITF': '3500000',
#   'DECIFR': '10',
#   'IDECIFR': '10',
#   'RDECIFR': '10',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '10',
#   'ADECIFR': '10',
#   'IPCF': '875000',
#   'DECCFR': '9',
#   'IDECCFR': '9',
#   'RDECCFR': '10',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '10',
#   'ADECCFR': '10',
#   'PONDIH': '765',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOSPRHLOLMCDEFOCD00804267',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '8',
#   'PONDERA': '325',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '2',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '2',
#   'IV6': '3',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '2',
#   'IV10': '2',
#   'IV11': '3',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '1',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '2',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '0',
#   'II5_1': '0',
#   'II6': '0',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '2',
#   'V1': '2',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '1',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '460000',
#   'DECIFR': '2',
#   'IDECIFR': '3',
#   'RDECIFR': '4',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '3',
#   'ADECIFR': '5',
#   'IPCF': '230000',
#   'DECCFR': '3',
#   'IDECCFR': '3',
#   'RDECCFR': '5',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '4',
#   'ADECCFR': '6',
#   'PONDIH': '363',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOPYUHMOLOCDEFOCD00866950',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '41',
#   'MAS_500': 'N',
#   'AGLOMERADO': '8',
#   'PONDERA': '365',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '2',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '4',
#   'ITF': '378000',
#   'DECIFR': '2',
#   'IDECIFR': '2',
#   'RDECIFR': '3',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '2',
#   'ADECIFR': '4',
#   'IPCF': '94500',
#   'DECCFR': '1',
#   'IDECCFR': '1',
#   'RDECCFR': '2',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '1',
#   'ADECCFR': '2',
#   'PONDIH': '389',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORQVHKKMMCDEIIAD00866951',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '32',
#   'PONDERA': '643',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '9',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '3',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '12',
#   'GDECIFR': '12',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '12',
#   'GDECCFR': '12',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '2',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOTQUHKLMNCDEIIAD00866952',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '32',
#   'PONDERA': '1826',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '1',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '1',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '3',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '2',
#   'V14': '1',
#   'V15': '1',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '12',
#   'GDECIFR': '12',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '12',
#   'GDECCFR': '12',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNORURHMKMNCDEIIAD00854820',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '32',
#   'PONDERA': '1427',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '2',
#   'V2': '1',
#   'V21': '1',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '1',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '1',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '12',
#   'GDECIFR': '12',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '12',
#   'GDECCFR': '12',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOQYQHMOMOCDEIIAD00812110',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '32',
#   'PONDERA': '1650',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '1',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '1240000',
#   'DECIFR': '7',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '7',
#   'GDECIFR': '7',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '5',
#   'IPCF': '620000',
#   'DECCFR': '8',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '8',
#   'GDECCFR': '8',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '5',
#   'PONDIH': '2779',
#   'VII1_1': '2',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOXWPHJOKMCDEIIAD00866953',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '32',
#   'PONDERA': '1319',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '2',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '1',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '3',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '3',
#   'ITF': '4100000',
#   'DECIFR': '10',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '10',
#   'GDECIFR': '10',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '10',
#   'IPCF': '1366666,67',
#   'DECCFR': '10',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '10',
#   'GDECCFR': '10',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '9',
#   'PONDIH': '1960',
#   'VII1_1': '96',
#   'VII1_2': '0',
#   'VII2_1': '1',
#   'VII2_2': '2',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOQVPHJNKNCDEIIAD00861810',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '32',
#   'PONDERA': '1736',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '9',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '2',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '249000',
#   'DECIFR': '1',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '1',
#   'GDECIFR': '1',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '1',
#   'IPCF': '249000',
#   'DECCFR': '4',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '3',
#   'GDECCFR': '3',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '1',
#   'PONDIH': '2366',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '96',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOPYXHKNKMCDEIIAD00866954',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '32',
#   'PONDERA': '2332',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '9',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '3',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '2',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '1800000',
#   'DECIFR': '9',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '8',
#   'GDECIFR': '9',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '7',
#   'IPCF': '1800000',
#   'DECCFR': '10',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '10',
#   'GDECCFR': '10',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '10',
#   'PONDIH': '2347',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '96',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOTRPHMKKTCDEIGED00867031',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '30',
#   'PONDERA': '190',
#   'IV1': '2',
#   'IV1_ESP': 'sin información',
#   'IV2': '1',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '1',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '3',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '200000',
#   'DECIFR': '1',
#   'IDECIFR': '1',
#   'RDECIFR': '1',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '1',
#   'ADECIFR': '1',
#   'IPCF': '200000',
#   'DECCFR': '3',
#   'IDECCFR': '3',
#   'RDECCFR': '2',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '3',
#   'ADECCFR': '3',
#   'PONDIH': '209',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOPVUHLLKTCDEIGED00811729',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '30',
#   'PONDERA': '112',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '4',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '4',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '1',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': '12',
#   'RDECIFR': '12',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '12',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': '12',
#   'RDECCFR': '12',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '12',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOQUUHLLKUCDEIGED00811707',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'N',
#   'AGLOMERADO': '30',
#   'PONDERA': '107',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '3',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '1',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '3',
#   'IX_MEN10': '1',
#   'IX_MAYEQ10': '2',
#   'ITF': '600000',
#   'DECIFR': '3',
#   'IDECIFR': '4',
#   'RDECIFR': '3',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '4',
#   'ADECIFR': '4',
#   'IPCF': '200000',
#   'DECCFR': '3',
#   'IDECCFR': '3',
#   'RDECCFR': '2',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '3',
#   'ADECCFR': '3',
#   'PONDIH': '132',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORVVHJLLRCDEIJAH00866190',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '33',
#   'PONDERA': '1122',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '4',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '3',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '4',
#   'II2': '3',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '4',
#   'ITF': '3900000',
#   'DECIFR': '10',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '10',
#   'GDECIFR': '10',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '10',
#   'IPCF': '975000',
#   'DECCFR': '9',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '9',
#   'GDECCFR': '9',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '10',
#   'PONDIH': '1538',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORURHLMKQCDEGOIH00867032',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '18',
#   'PONDERA': '240',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '740000',
#   'DECIFR': '4',
#   'IDECIFR': '5',
#   'RDECIFR': '5',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '5',
#   'ADECIFR': '5',
#   'IPCF': '370000',
#   'DECCFR': '6',
#   'IDECCFR': '6',
#   'RDECCFR': '7',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '6',
#   'ADECCFR': '8',
#   'PONDIH': '258',
#   'VII1_1': '97',
#   'VII1_2': '0',
#   'VII2_1': '1',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOXYPHLOKRCDEGOIH00805420',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '18',
#   'PONDERA': '1737',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '3',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '1',
#   'V15': '1',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '2',
#   'IX_MAYEQ10': '2',
#   'ITF': '360000',
#   'DECIFR': '2',
#   'IDECIFR': '2',
#   'RDECIFR': '2',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '2',
#   'ADECIFR': '2',
#   'IPCF': '90000',
#   'DECCFR': '1',
#   'IDECCFR': '1',
#   'RDECCFR': '1',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '1',
#   'ADECCFR': '1',
#   'PONDIH': '1648',
#   'VII1_1': '2',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORYRHJOLQCDEGOIH00866678',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '18',
#   'PONDERA': '168',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '4',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '3',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '1',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '7',
#   'IX_MEN10': '2',
#   'IX_MAYEQ10': '5',
#   'ITF': '750000',
#   'DECIFR': '4',
#   'IDECIFR': '5',
#   'RDECIFR': '5',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '5',
#   'ADECIFR': '5',
#   'IPCF': '107142,86',
#   'DECCFR': '1',
#   'IDECCFR': '1',
#   'RDECCFR': '2',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '1',
#   'ADECCFR': '2',
#   'PONDIH': '181',
#   'VII1_1': '2',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Extendido'},
#  {'CODUSU': 'TQRMNOQPQHLMLQCDEHMHF00806179',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '42',
#   'MAS_500': 'N',
#   'AGLOMERADO': '26',
#   'PONDERA': '155',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '1',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '4',
#   'ITF': '640000',
#   'DECIFR': '4',
#   'IDECIFR': '4',
#   'RDECIFR': '4',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '4',
#   'ADECIFR': '4',
#   'IPCF': '160000',
#   'DECCFR': '2',
#   'IDECCFR': '2',
#   'RDECCFR': '2',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '2',
#   'ADECCFR': '2',
#   'PONDIH': '205',
#   'VII1_1': '1',
#   'VII1_2': '4',
#   'VII2_1': '8',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORRPHLOKQCDEGPDJ00805603',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '2',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '19',
#   'PONDERA': '229',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '1',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '2',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '2',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '1',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '1',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
# ...
#   'ADECCFR': '9',
#   'PONDIH': '1592',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOTPPHLOLSCDEGJBF00804846',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '43',
#   'MAS_500': 'S',
#   'AGLOMERADO': '13',
#   'PONDERA': '798',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '2',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '1',
#   'V21': '2',
#   'V22': '1',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '1',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '1',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '1',
#   'IX_MAYEQ10': '3',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': '12',
#   'RDECIFR': '12',
#   'GDECIFR': '12',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': '12',
#   'RDECCFR': '12',
#   'GDECCFR': '12',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '3',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOTPXHJMMPCDEIJAH00861821',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '33',
#   'PONDERA': '782',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '2',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '2',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '2',
#   'IV11': '2',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '3',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '3',
#   'ITF': '600000',
#   'DECIFR': '3',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '3',
#   'GDECIFR': '3',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '3',
#   'IPCF': '200000',
#   'DECCFR': '3',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '3',
#   'GDECCFR': '3',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '3',
#   'PONDIH': '1591',
#   'VII1_1': '1',
#   'VII1_2': '2',
#   'VII2_1': '3',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOQWVHKOMMCDEIJAH00867908',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '33',
#   'PONDERA': '1688',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '2',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '1',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '1',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '1',
#   'ITF': '0',
#   'DECIFR': '12',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '12',
#   'GDECIFR': '12',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '12',
#   'IPCF': '0',
#   'DECCFR': '12',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '12',
#   'GDECCFR': '12',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '12',
#   'PONDIH': '0',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Unipersonal'},
#  {'CODUSU': 'TQRMNOTQRHMMMRCDEIJAH00867909',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '33',
#   'PONDERA': '2462',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '1',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '2',
#   'IV5': '2',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '1',
#   'II2': '1',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '2',
#   'II4_2': '2',
#   'II4_3': '2',
#   'II5': '0',
#   'II5_1': '0',
#   'II6': '0',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '1',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '2',
#   'IX_MAYEQ10': '2',
#   'ITF': '600000',
#   'DECIFR': '3',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '3',
#   'GDECIFR': '3',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '3',
#   'IPCF': '150000',
#   'DECCFR': '2',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '2',
#   'GDECCFR': '2',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '2',
#   'PONDIH': '3890',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORYTHJOKMCDEGOIH00862250',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '18',
#   'PONDERA': '143',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '2',
#   'V14': '2',
#   'V15': '1',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '550000',
#   'DECIFR': '3',
#   'IDECIFR': '3',
#   'RDECIFR': '3',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '4',
#   'ADECIFR': '3',
#   'IPCF': '275000',
#   'DECCFR': '4',
#   'IDECCFR': '4',
#   'RDECCFR': '6',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '5',
#   'ADECCFR': '6',
#   'PONDIH': '140',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOSPSHJOKMCDEGOIH00862194',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '18',
#   'PONDERA': '104',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '3',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '1',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '4',
#   'ITF': '700000',
#   'DECIFR': '4',
#   'IDECIFR': '4',
#   'RDECIFR': '5',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '5',
#   'ADECIFR': '5',
#   'IPCF': '175000',
#   'DECCFR': '2',
#   'IDECCFR': '2',
#   'RDECCFR': '3',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '3',
#   'ADECCFR': '4',
#   'PONDIH': '103',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNPXYXHMOKMCDEGOIH00810565',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '18',
#   'PONDERA': '660',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '1',
#   'V14': '1',
#   'V15': '1',
#   'V16': '1',
#   'V17': '1',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '2',
#   'IX_MAYEQ10': '2',
#   'ITF': '606000',
#   'DECIFR': '3',
#   'IDECIFR': '4',
#   'RDECIFR': '4',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '4',
#   'ADECIFR': '4',
#   'IPCF': '151500',
#   'DECCFR': '2',
#   'IDECCFR': '2',
#   'RDECCFR': '3',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '2',
#   'ADECCFR': '3',
#   'PONDIH': '672',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOPQQHJOKQCDEGOIH00862135',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '40',
#   'MAS_500': 'N',
#   'AGLOMERADO': '18',
#   'PONDERA': '260',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '4',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '4',
#   'II2': '3',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '1',
#   'V21': '1',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '1',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '3',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '3',
#   'ITF': '1160000',
#   'DECIFR': '7',
#   'IDECIFR': '7',
#   'RDECIFR': '8',
#   'GDECIFR': 'sin información',
#   'PDECIFR': '7',
#   'ADECIFR': '8',
#   'IPCF': '386666,67',
#   'DECCFR': '6',
#   'IDECCFR': '6',
#   'RDECCFR': '8',
#   'GDECCFR': 'sin información',
#   'PDECCFR': '7',
#   'ADECCFR': '8',
#   'PONDIH': '261',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '3',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNORTWHMMSUCDEIJAH00812720',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '33',
#   'PONDERA': '798',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '3',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '1',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '1',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '3',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '2',
#   'II4_2': '1',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '1',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '1',
#   'V21': '2',
#   'V22': '1',
#   'V3': '2',
#   'V4': '2',
#   'V5': '2',
#   'V6': '2',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '2',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '1',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '2',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '2',
#   'ITF': '1770000',
#   'DECIFR': '9',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '8',
#   'GDECIFR': '8',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '9',
#   'IPCF': '885000',
#   'DECCFR': '9',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '9',
#   'GDECCFR': '9',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '9',
#   'PONDIH': '1386',
#   'VII1_1': '2',
#   'VII1_2': '0',
#   'VII2_1': '98',
#   'VII2_2': '0',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  {'CODUSU': 'TQRMNOSYTHMOQQCDEIJAH00812653',
#   'ANO4': '2024',
#   'TRIMESTRE': '3',
#   'NRO_HOGAR': '1',
#   'REALIZADA': '1',
#   'REGION': '1',
#   'MAS_500': 'S',
#   'AGLOMERADO': '33',
#   'PONDERA': '1731',
#   'IV1': '1',
#   'IV1_ESP': 'sin información',
#   'IV2': '2',
#   'IV3': '1',
#   'IV3_ESP': 'sin información',
#   'IV4': '4',
#   'IV5': '1',
#   'IV6': '1',
#   'IV7': '1',
#   'IV7_ESP': 'sin información',
#   'IV8': '1',
#   'IV9': '1',
#   'IV10': '1',
#   'IV11': '2',
#   'IV12_1': '2',
#   'IV12_2': '2',
#   'IV12_3': '2',
#   'II1': '2',
#   'II2': '2',
#   'II3': '2',
#   'II3_1': '0',
#   'II4_1': '1',
#   'II4_2': '2',
#   'II4_3': '1',
#   'II5': '2',
#   'II5_1': '0',
#   'II6': '2',
#   'II6_1': '0',
#   'II7': '1',
#   'II7_ESP': 'sin información',
#   'II8': '2',
#   'II8_ESP': 'sin información',
#   'II9': '1',
#   'V1': '1',
#   'V2': '2',
#   'V21': '2',
#   'V22': '2',
#   'V3': '2',
#   'V4': '2',
#   'V5': '1',
#   'V6': '1',
#   'V7': '2',
#   'V8': '2',
#   'V9': '2',
#   'V10': '2',
#   'V11': '1',
#   'V12': '2',
#   'V13': '2',
#   'V14': '2',
#   'V15': '2',
#   'V16': '2',
#   'V17': '2',
#   'V18': '2',
#   'V19_A': '2',
#   'V19_B': '2',
#   'IX_TOT': '4',
#   'IX_MEN10': '0',
#   'IX_MAYEQ10': '4',
#   'ITF': '255000',
#   'DECIFR': '1',
#   'IDECIFR': 'sin información',
#   'RDECIFR': '1',
#   'GDECIFR': '1',
#   'PDECIFR': 'sin información',
#   'ADECIFR': '1',
#   'IPCF': '63750',
#   'DECCFR': '1',
#   'IDECCFR': 'sin información',
#   'RDECCFR': '1',
#   'GDECCFR': '1',
#   'PDECCFR': 'sin información',
#   'ADECCFR': '1',
#   'PONDIH': '2698',
#   'VII1_1': '1',
#   'VII1_2': '0',
#   'VII2_1': '3',
#   'VII2_2': '4',
#   'VII2_3': '0',
#   'VII2_4': '0',
#   'TIPO_HOGAR': 'Nuclear'},
#  ...]

# %% [markdown]
# 8. La funcion material_techumbre genera una columna en hogares para modificar los valores numericos obtenidos en el campo IV4 para agregarlos en la nueva columna denominada igual a la funcion de tipo cadena de texo con los siguientes valores: "Material precario" = (1 a 4), "Material durable" = (5 a 7) y "No aplica" = (9)

# %%
from materialhogares import material_techumbre

material_techumbre(hogares)

# %% [markdown]
# 9. La funcion key_densidad_hogar del modulo densidad_hogar agrega una nueva columna (key) a la variable hogares (pasada como parametro) y agrega valores en base a la cantidad de habitaciones por persona

# %%
from densidad_hogar import key_densidad_hogar

key_densidad_hogar(hogares)

# %% [markdown]
# 10. Esta función se encarga de agregar una nueva columna que determina la condición de habitabilidad, en base a datos almacenados sobre el acceso al agua, su origen, la presencia de baño, entre otros. De esta manera, se podrá clasificar la condición del hogar como insuficiente, regular, saludable o buena.

# %%
from cond_hab import condicion_de_habitabilidad

condicion_de_habitabilidad(hogares)

# %% [markdown]
# Creacion del archivo csv para Hogares

# %%
ds.guardar_como_csv ('HogaresTotal',hogares)
# Out:
# ✅ Archivo HogaresTotal guardado en: C:\Users\usuario\Desktop\TP GITLAB\code\INDEC\utils\HogaresTotal.csv
