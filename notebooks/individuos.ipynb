# %% [markdown]
# Desarrollo del archivo Individuos

# %%
import sys
import os

#Definicion de rutas
sys.path.append(os.path.abspath('../src'))
sys.path.append(os.path.abspath("../src/funciones"))
sys.path.append(os.path.abspath("../utils"))

#Importacion de funciones propias
import DataSet as ds
from constantes import DATA_PATH
from generos_str import int_to_str 
from nivel_ed import key_nivel_ed_str
from cond_lab import condicion_laboral
from univ_num import add_uni

#Creacion y limpieza de DataSet
individuos_sucio = ds.dataset_individuals(DATA_PATH)
individuos = ds.limpieza_dataset(individuos_sucio)

#Llamado de funciones
int_to_str(individuos)
key_nivel_ed_str(individuos)
condicion_laboral(individuos)
add_uni(individuos)
ds.guardar_como_csv ('IndividuosTotal',individuos)
# Out:
# ✅ Se cargaron 152187 registros de individuos.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 22
#      19 individuos = ds.limpieza_dataset(individuos_sucio)
#      21 #Llamado de funciones
# ---> 22 int_to_str(individuos)
#      23 key_nivel_ed_str(individuos)
#      24 condicion_laboral(individuos)
#
# File ~/Escritorio/TPindec/src/funciones/generos_str.py:12, in int_to_str(list_disc_indi)
#       1 def int_to_str (list_disc_indi):
#       2     """cambia losv alores de CH04 de integer a string
#       3         valor 1 = Masculino.
#       4         valor 2 = Femenino.
#    (...)     10         _type_: los devuelve ya modificados
#      11     """
# ---> 12     for i,dict in enumerate(list_disc_indi):
#      13         if list_disc_indi[i]['CH04'] == '1':
#      14                 list_disc_indi[i]['CH04_str'] = 'Masculino'
#
# TypeError: 'NoneType' object is not iterable
